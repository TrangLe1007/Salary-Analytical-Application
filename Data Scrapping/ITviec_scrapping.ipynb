# %%
# Import library
import requests
from bs4 import BeautifulSoup as bs
from datetime import date
import pandas as pd

# %%
#Create empty list to store data
lst_salary=[]
lst_title=[]
lst_link=[]
lst_address=[]
lst_company_link=[]

url="https://itviec.com/it-jobs?page=1&source=search_job"

#create a loop to get data from mutiple pages
while True:
    #salary info of jobs are hidden behind a login thus need to identify what authorization technique is used
    session = "me8hiBHiyQFuqQtwhcJvc%2F7VY76hBZ1YJUrKFtHo33X2gqMJi%2BKE4IBjOHvUAv04Wf13cqiYpG6nkKdvEFeoqkmWAyxJKRw2DT%2FIZlfrlz9OmKmDtDHA2%2B%2Bx6%2FHtfdFuk7pci8X7eHaST1DkVdHQ1LTKepu%2FMYZh4i9YaS7NHfn7ehQEmdNQ%2FZN%2Fm23N6zAMHbk7hKsTY6GJgTJEnYwEjws0%2BLQKpMFetRH%2Fl2cJz6pNVyi73KLP6G57a51mI2%2FOl2GIGczsiNib7L1RFp7J0zBJRIEVM9VZlndOvEiGH0ernBweXP%2Bf%2Bd5Jso4DNAU7FWWlsm7wA4k0Ov%2B%2Bda6%2FRGj4GlLD7B49OOoPf4d9naju8aL7rv28wN2wlLUa5Cf%2FJ%2FQGsX03atU5X6Nf2ZkT19uiL7%2BId6s12UFI3uJzenNumZ8OZ77Hok858r%2BLArWhudXHG2VfCbwUhmnCd9LU%2FZoW5qdfVLUrIeM%2BREsqAcHIfoj7o1UUZkAiPaVWb6rrOKrqZ1v%2B%2BcalN3IFlXU4A5sCh5h%2BiTIR%2FXj6btzFs6savBsZ6o8zICdd%2FA%3D%3D--lXzLNRifcvWXIBcy--Y8hcw6q38FGr%2FUNbQTBSog%3D%3D; path=/; HttpOnly; SameSite=Lax"   
   
    # attach ID into each request's cookie to trick the server that this request is made by a valid, logged-in user 
    response = requests.get(url,cookies={'_ITViec_session': session})
    data=response.text
    soup=bs(data,"html.parser")

    #scrape data
    salary=soup.findAll("div",{"class":"svg-icon__text"})
    for i in salary:
        lst_salary.append(i.text)
    box=soup.findAll("h2",{"class":"title"})
    for j in box:
        link=j.find("a").get("href")
        lst_link.append(link)
        title=j.find("a").text
        lst_title.append(title)
    address=soup.findAll("span",{"class":"text"})
    for f in address:
        lst_address.append(f.text)
    link_company=soup.findAll("div",{"class":"logo-wrapper"})
    for k in link_company:
        link_lst=k.find("a").get("href")
        lst_company_link.append(link_lst)

    url_tag=soup.find('a',{'rel':'next'})
    if url_tag["href"]!=None: 
        url="https://itviec.com/"+ url_tag["href"]
        print(url)
    else:
        break
# Out:
# https://itviec.com//it-jobs?page=2&query=&source=search_job
# https://itviec.com//it-jobs?page=3&query=&source=search_job
# https://itviec.com//it-jobs?page=4&query=&source=search_job
# https://itviec.com//it-jobs?page=5&query=&source=search_job
# https://itviec.com//it-jobs?page=6&query=&source=search_job
# https://itviec.com//it-jobs?page=7&query=&source=search_job
# https://itviec.com//it-jobs?page=8&query=&source=search_job
# https://itviec.com//it-jobs?page=9&query=&source=search_job
# https://itviec.com//it-jobs?page=10&query=&source=search_job
# https://itviec.com//it-jobs?page=11&query=&source=search_job
# https://itviec.com//it-jobs?page=12&query=&source=search_job
# https://itviec.com//it-jobs?page=13&query=&source=search_job
# https://itviec.com//it-jobs?page=14&query=&source=search_job
# https://itviec.com//it-jobs?page=15&query=&source=search_job
# https://itviec.com//it-jobs?page=16&query=&source=search_job
# https://itviec.com//it-jobs?page=17&query=&source=search_job
# https://itviec.com//it-jobs?page=18&query=&source=search_job
# https://itviec.com//it-jobs?page=19&query=&source=search_job
# https://itviec.com//it-jobs?page=20&query=&source=search_job
# https://itviec.com//it-jobs?page=21&query=&source=search_job
# https://itviec.com//it-jobs?page=22&query=&source=search_job
# https://itviec.com//it-jobs?page=23&query=&source=search_job
# https://itviec.com//it-jobs?page=24&query=&source=search_job
# https://itviec.com//it-jobs?page=25&query=&source=search_job
# https://itviec.com//it-jobs?page=26&query=&source=search_job
# https://itviec.com//it-jobs?page=27&query=&source=search_job
# https://itviec.com//it-jobs?page=28&query=&source=search_job
# https://itviec.com//it-jobs?page=29&query=&source=search_job
# https://itviec.com//it-jobs?page=30&query=&source=search_job
# https://itviec.com//it-jobs?page=31&query=&source=search_job
# https://itviec.com//it-jobs?page=32&query=&source=search_job
# https://itviec.com//it-jobs?page=33&query=&source=search_job
# https://itviec.com//it-jobs?page=34&query=&source=search_job
# https://itviec.com//it-jobs?page=35&query=&source=search_job
# https://itviec.com//it-jobs?page=36&query=&source=search_job
# https://itviec.com//it-jobs?page=37&query=&source=search_job
# https://itviec.com//it-jobs?page=38&query=&source=search_job
# https://itviec.com//it-jobs?page=39&query=&source=search_job
# https://itviec.com//it-jobs?page=40&query=&source=search_job
# https://itviec.com//it-jobs?page=41&query=&source=search_job
# https://itviec.com//it-jobs?page=42&query=&source=search_job
# https://itviec.com//it-jobs?page=43&query=&source=search_job
# https://itviec.com//it-jobs?page=44&query=&source=search_job
# https://itviec.com//it-jobs?page=45&query=&source=search_job
# https://itviec.com//it-jobs?page=46&query=&source=search_job
# https://itviec.com//it-jobs?page=47&query=&source=search_job
# https://itviec.com//it-jobs?page=48&query=&source=search_job
# https://itviec.com//it-jobs?page=49&query=&source=search_job
# https://itviec.com//it-jobs?page=50&query=&source=search_job
# https://itviec.com//it-jobs?page=51&query=&source=search_job
# https://itviec.com//it-jobs?page=52&query=&source=search_job
# https://itviec.com//it-jobs?page=53&query=&source=search_job
# https://itviec.com//it-jobs?page=54&query=&source=search_job
# https://itviec.com//it-jobs?page=55&query=&source=search_job
# https://itviec.com//it-jobs?page=56&query=&source=search_job
# https://itviec.com//it-jobs?page=57&query=&source=search_job
# https://itviec.com//it-jobs?page=58&query=&source=search_job
# https://itviec.com//it-jobs?page=59&query=&source=search_job
# https://itviec.com//it-jobs?page=60&query=&source=search_job
# https://itviec.com//it-jobs?page=61&query=&source=search_job
# https://itviec.com//it-jobs?page=62&query=&source=search_job
# https://itviec.com//it-jobs?page=63&query=&source=search_job
# https://itviec.com//it-jobs?page=64&query=&source=search_job
# https://itviec.com//it-jobs?page=65&query=&source=search_job
# https://itviec.com//it-jobs?page=66&query=&source=search_job
# https://itviec.com//it-jobs?page=67&query=&source=search_job
# https://itviec.com//it-jobs?page=68&query=&source=search_job
# https://itviec.com//it-jobs?page=69&query=&source=search_job
# https://itviec.com//it-jobs?page=70&query=&source=search_job
# https://itviec.com//it-jobs?page=71&query=&source=search_job
# https://itviec.com//it-jobs?page=72&query=&source=search_job
# https://itviec.com//it-jobs?page=73&query=&source=search_job
# https://itviec.com//it-jobs?page=74&query=&source=search_job
# https://itviec.com//it-jobs?page=75&query=&source=search_job
# https://itviec.com//it-jobs?page=76&query=&source=search_job
# https://itviec.com//it-jobs?page=77&query=&source=search_job
# https://itviec.com//it-jobs?page=78&query=&source=search_job
# https://itviec.com//it-jobs?page=79&query=&source=search_job
# https://itviec.com//it-jobs?page=80&query=&source=search_job
# https://itviec.com//it-jobs?page=81&query=&source=search_job
# https://itviec.com//it-jobs?page=82&query=&source=search_job
# https://itviec.com//it-jobs?page=83&query=&source=search_job
# https://itviec.com//it-jobs?page=84&query=&source=search_job
# https://itviec.com//it-jobs?page=85&query=&source=search_job
# https://itviec.com//it-jobs?page=86&query=&source=search_job
# https://itviec.com//it-jobs?page=87&query=&source=search_job
# https://itviec.com//it-jobs?page=88&query=&source=search_job
# https://itviec.com//it-jobs?page=89&query=&source=search_job
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-53dee04708c3> in <module>
#      37
#      38     url_tag=soup.find('a',{'rel':'next'})
# ---> 39     if url_tag["href"]!=None:
#      40         url="https://itviec.com/"+ url_tag["href"]
#      41         print(url)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
#create a dictionary to store list of data
database = {'Title_job': lst_title,
            'Job_link':lst_link,
            'Company_link':lst_company_link,
            'Address':lst_address,
            'Salary':lst_salary  
            }
#convert dictionary to dataframe by Pandas            
df = pd.DataFrame.from_dict(database, orient='index')

df = df.transpose()
#add column 'date' to save the day of scraping
df['date'] = pd.to_datetime('today').strftime("%m/%d/%Y")

#create a newCSV file
df.to_csv('IT_job_Database_1710.csv',encoding='utf-8-sig')
#append dataframe into the exist CSV file
df.to_csv('IT_job_Database - Staging.csv', mode='a', index=True, header=False)

#check the first of 5 lines of table
df.head(5)
# Out:
#                                 Title_job  \
# 0                   Frontend Tech lead x5
# 1        Infrastructure/DevOps Specialist
# 2           Senior Ruby on Rails Engineer
# 3        [HN, HCM] Senior Data Architect
# 4  12 Junior Java Dev (Spring, AngularJS)
#
#                                             Job_link  \
# 0  /it-jobs/frontend-tech-lead-x5-niteco-vietnam-...
# 1  /it-jobs/infrastructure-devops-specialist-nite...
# 2  /it-jobs/senior-ruby-on-rails-engineer-positiv...
# 3  /it-jobs/hn-hcm-senior-data-architect-techcomb...
# 4  /it-jobs/12-junior-java-dev-spring-angularjs-v...
#
#                                  Company_link      Address          Salary  \
# 0            /companies/niteco-vietnam-co-ltd       Ha Noi  You'll love it
# 1            /companies/niteco-vietnam-co-ltd       Ha Noi  You'll love it
# 2  /companies/positive-thinking-company-b-o-t  Ho Chi Minh  You'll love it
# 3                      /companies/techcombank       Ha Noi  You'll love it
# 4                  /companies/vnpt-technology  Ho Chi Minh  You'll love it
#
#          date
# 0  10/17/2021
# 1  10/17/2021
# 2  10/17/2021
# 3  10/17/2021
# 4  10/17/2021
