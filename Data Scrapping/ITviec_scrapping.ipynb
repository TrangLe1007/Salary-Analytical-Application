# %%
import requests
from bs4 import BeautifulSoup as bs
from datetime import date
import pandas as pd

# %%
#Create empty list to store data
lst_salary=[]
lst_title=[]
lst_link=[]
lst_address=[]
lst_company_link=[]

url="https://itviec.com/it-jobs?page=1&source=search_job"

#create a loop to get data from mutiple pages
while True:
    #salary info of jobs are hidden behind a login thus need to identify what authorization technique is used
    session = "N5MRJF8QM5vIMavTZjGpVNwUEvNY3dC22JpgT%2F2xZOeiOJCcA2TwglX3iL66LRWFrTiaKNaMkK%2BfCdTLeAVP765d5SQEZn4PZf5e8y9Y%2Ba2iFMQoW%2Bj8un7aPr3FnqC13FKT%2Bm6yJ7xOd%2B48prHIfxq9kVs1P1C7ZM%2BUb8uq8%2FHguSqbvGQEEEeTdT6d63RxrWemo98Mvz5WNlC9%2FGOZQkFCOJCh9L6JEUe9SNYr6v6ThBAKvfMU1YzePVcD89FuLsrdtUHW8D3A532PYM74ZRZgq65dd0PqqBI5Yyk76FvU9wKGDIDOwJvhwfNIKmprxSySxV7bvM2CffzuMvW9dqDOJEV9Wh3v%2BOdq4ps3gt9drOVpdAkALe3sFVu5xqq64FNWtPjk6VJg4irdqC36YMmXGvvZoejb%2FuzB3O0PN%2FUPj2rlezHX%2BVPvDzay7zi1v2g6ghE5RmZlo0c1jjvALq1HYpQnTJt3Lo00c%2BEp0XI3TtrD2aYwHPi7GvEKF8CjjO88k10hE10LW8taHe6epE1KzKSYUNwi9WuQ61VPPbWQWMtkRg6H8CHs6w%3D%3D--m%2BHtTKnc9d%2Fcwldl--9isWji1wkVTPrwhzOL9DhA%3D%3D; path=/; HttpOnly; SameSite=Lax"   
   
    # attach ID into each request's cookie to trick the server that this request is made by a valid, logged-in user 
    response = requests.get(url,cookies={'_ITViec_session': session})
    data=response.text
    soup=bs(data,"html.parser")

    #scrape data
    salary=soup.findAll("div",{"class":"svg-icon__text"})
    for i in salary:
        lst_salary.append(i.text)
    box=soup.findAll("h2",{"class":"title"})
    for j in box:
        link=j.find("a").get("href")
        lst_link.append(link)
        title=j.find("a").text
        lst_title.append(title)
    address=soup.findAll("span",{"class":"text"})
    for f in address:
        lst_address.append(f.text)
    link_company=soup.findAll("div",{"class":"logo-wrapper"})
    for k in link_company:
        link_lst=k.find("a").get("href")
        lst_company_link.append(link_lst)

    url_tag=soup.find('a',{'rel':'next'})
    if url_tag["href"]!=None: 
        url="https://itviec.com/"+ url_tag["href"]
        print(url)
    else:
        break
# Out:
# https://itviec.com//it-jobs/?page=2&source=search_job
# https://itviec.com//it-jobs/?page=3&source=search_job
# https://itviec.com//it-jobs/?page=4&source=search_job
# https://itviec.com//it-jobs/?page=5&source=search_job
# https://itviec.com//it-jobs/?page=6&source=search_job
# https://itviec.com//it-jobs/?page=7&source=search_job
# https://itviec.com//it-jobs/?page=8&source=search_job
# https://itviec.com//it-jobs/?page=9&source=search_job
# https://itviec.com//it-jobs/?page=10&source=search_job
# https://itviec.com//it-jobs/?page=11&source=search_job
# https://itviec.com//it-jobs/?page=12&source=search_job
# https://itviec.com//it-jobs/?page=13&source=search_job
# https://itviec.com//it-jobs/?page=14&source=search_job
# https://itviec.com//it-jobs/?page=15&source=search_job
# https://itviec.com//it-jobs/?page=16&source=search_job
# https://itviec.com//it-jobs/?page=17&source=search_job
# https://itviec.com//it-jobs/?page=18&source=search_job
# https://itviec.com//it-jobs/?page=19&source=search_job
# https://itviec.com//it-jobs/?page=20&source=search_job
# https://itviec.com//it-jobs/?page=21&source=search_job
# https://itviec.com//it-jobs/?page=22&source=search_job
# https://itviec.com//it-jobs/?page=23&source=search_job
# https://itviec.com//it-jobs/?page=24&source=search_job
# https://itviec.com//it-jobs/?page=25&source=search_job
# https://itviec.com//it-jobs/?page=26&source=search_job
# https://itviec.com//it-jobs/?page=27&source=search_job
# https://itviec.com//it-jobs/?page=28&source=search_job
# https://itviec.com//it-jobs/?page=29&source=search_job
# https://itviec.com//it-jobs/?page=30&source=search_job
# https://itviec.com//it-jobs/?page=31&source=search_job
# https://itviec.com//it-jobs/?page=32&source=search_job
# https://itviec.com//it-jobs/?page=33&source=search_job
# https://itviec.com//it-jobs/?page=34&source=search_job
# https://itviec.com//it-jobs/?page=35&source=search_job
# https://itviec.com//it-jobs/?page=36&source=search_job
# https://itviec.com//it-jobs/?page=37&source=search_job
# https://itviec.com//it-jobs/?page=38&source=search_job
# https://itviec.com//it-jobs/?page=39&source=search_job
# https://itviec.com//it-jobs/?page=40&source=search_job
# https://itviec.com//it-jobs/?page=41&source=search_job
# https://itviec.com//it-jobs/?page=42&source=search_job
# https://itviec.com//it-jobs/?page=43&source=search_job
# https://itviec.com//it-jobs/?page=44&source=search_job
# https://itviec.com//it-jobs/?page=45&source=search_job
# https://itviec.com//it-jobs/?page=46&source=search_job
# https://itviec.com//it-jobs/?page=47&source=search_job
# https://itviec.com//it-jobs/?page=48&source=search_job
# https://itviec.com//it-jobs/?page=49&source=search_job
# https://itviec.com//it-jobs/?page=50&source=search_job
# https://itviec.com//it-jobs/?page=51&source=search_job
# https://itviec.com//it-jobs/?page=52&source=search_job
# https://itviec.com//it-jobs/?page=53&source=search_job
# https://itviec.com//it-jobs/?page=54&source=search_job
# https://itviec.com//it-jobs/?page=55&source=search_job
# https://itviec.com//it-jobs/?page=56&source=search_job
# https://itviec.com//it-jobs/?page=57&source=search_job
# https://itviec.com//it-jobs/?page=58&source=search_job
# https://itviec.com//it-jobs/?page=59&source=search_job
# https://itviec.com//it-jobs/?page=60&source=search_job
# https://itviec.com//it-jobs/?page=61&source=search_job
# https://itviec.com//it-jobs/?page=62&source=search_job
# https://itviec.com//it-jobs/?page=63&source=search_job
# https://itviec.com//it-jobs/?page=64&source=search_job
# https://itviec.com//it-jobs/?page=65&source=search_job
# https://itviec.com//it-jobs/?page=66&source=search_job
# https://itviec.com//it-jobs/?page=67&source=search_job
# https://itviec.com//it-jobs/?page=68&source=search_job
# https://itviec.com//it-jobs/?page=69&source=search_job
# https://itviec.com//it-jobs/?page=70&source=search_job
# https://itviec.com//it-jobs/?page=71&source=search_job
# https://itviec.com//it-jobs/?page=72&source=search_job
# https://itviec.com//it-jobs/?page=73&source=search_job
# https://itviec.com//it-jobs/?page=74&source=search_job
# https://itviec.com//it-jobs/?page=75&source=search_job
# https://itviec.com//it-jobs/?page=76&source=search_job
# https://itviec.com//it-jobs/?page=77&source=search_job
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-4701a82a7fbb> in <module>
#      37
#      38     url_tag=soup.find('a',{'rel':'next'})
# ---> 39     if url_tag["href"]!=None:
#      40         url="https://itviec.com/"+ url_tag["href"]
#      41         print(url)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
#create a dictionary to store list of data
database = {'Title_job': lst_title,
            'Job_link':lst_link,
            'Company_link':lst_company_link,
            'Address':lst_address,
            'Salary':lst_salary  
            }
#convert dictionary to dataframe by Pandas            
df = pd.DataFrame.from_dict(database, orient='index')

df = df.transpose()
#add column 'date' to save the day of scraping
df['date'] = pd.to_datetime('today').strftime("%m/%d/%Y")

#append dataframe into the exist CSV file

# df.to_csv('IT_job_Database_16708.csv',encoding='utf-8-sig')
df.to_csv('IT_job_Database - Staging.csv', mode='a', index=True, header=False)

#check the first of 5 lines of table
df.head(5)
# Out:
#                                  Title_job  \
# 0     Jr. Mobile Developer (Swift, Kotlin)
# 1                   3 .net core developers
# 2            Omni-channel Technical leader
# 3                   Senior System Engineer
# 4  (Senior) .NET Developer (.NET Core, C#)
#
#                                             Job_link  \
# 0  /it-jobs/jr-mobile-developer-swift-kotlin-go2j...
# 1      /it-jobs/3-net-core-developers-hdwebsoft-5446
# 2  /it-jobs/omni-channel-technical-leader-central...
# 3  /it-jobs/senior-system-engineer-orient-softwar...
# 4  /it-jobs/senior-net-developer-net-core-c-titan...
#
#                                   Company_link      Address  \
# 0                            /companies/go2joy  Ho Chi Minh
# 1                         /companies/hdwebsoft  Ho Chi Minh
# 2                    /companies/central-retail  Ho Chi Minh
# 3  /companies/orient-software-development-corp      Da Nang
# 4      /companies/titan-technology-corporation  Ho Chi Minh
#
#               Salary        date
# 0     You'll love it  08/17/2021
# 1     You'll love it  08/17/2021
# 2  1,500 - 3,000 USD  08/17/2021
# 3     You'll love it  08/17/2021
# 4     You'll love it  08/17/2021
